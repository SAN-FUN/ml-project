# %% [markdown]
# <a href="https://colab.research.google.com/github/SAN-FUN/ml-project/blob/main/Dataprep_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'City': ['Mumbai', 'Delhi', 'Chennai', 'Mumbai', 'Delhi'],
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small'],
    'Age': [25, 45, 32, 60, 28],
    'Fare': [15, 300, 85, 450, 20]
}

df = pd.DataFrame(data)
# 1. Gender → Label Encoding
# -------------------------------
le_gender = LabelEncoder()
df['Gender'] = le_gender.fit_transform(df['Gender'])

# -------------------------------
# 2. City → One-Hot Encoding
# (drop one column to avoid dummy variable trap)
# -------------------------------
df = pd.get_dummies(df, columns=['City'], drop_first=True)

# -------------------------------
# 3. Size → Ordinal Encoding
# Small=0, Medium=1, Large=2
# -------------------------------
size_mapping = {'Small': 0, 'Medium': 1, 'Large': 2}
df['Size'] = df['Size'].map(size_mapping)

print("Encoded Data:")
print(df)
# Out:
# Encoded Data:
#    Gender  Size  Age  Fare  City_Delhi  City_Mumbai
# 0       1     0   25    15       False         True
# 1       0     2   45   300        True        False
# 2       0     1   32    85       False        False
# 3       1     2   60   450       False         True
# 4       0     0   28    20        True        False

# %% [markdown]
# Robustscaler used as fare column has outliers and it is less sensitive to extreme values

# %%
#Task 2 — Feature Scaling
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

print("\nScaled Data:")
print(df)
# Out:
# Scaled Data:
#    Gender  Size       Age      Fare  City_Delhi  City_Mumbai
# 0       1     0 -0.411765 -0.250000       False         True
# 1       0     2  0.764706  0.767857        True        False
# 2       0     1  0.000000  0.000000       False        False
# 3       1     2  1.647059  1.303571       False         True
# 4       0     0 -0.235294 -0.232143        True        False
